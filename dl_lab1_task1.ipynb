# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/BilalR4M/dl_lab1/blob/main/dl_lab1_task1.ipynb)

# %% [markdown]
# **DL lab 1 IT22548900 Bilal R A M**

# %% [markdown]
# Task 1
# 1. Create a random 4x4 array from an exponential distribution. Refer numpy functions.

# %%
import numpy as np
# Create a random 4x4 array from an exponential distribution
# using numpy.random.exponential()
exponential_array = np.random.exponential(scale=1.0, size=(4, 4))
print("Random 4x4 array from exponential distribution:")
print(exponential_array)
# Out:
# Random 4x4 array from exponential distribution:
# [[0.43805503 1.55314172 0.48492411 0.23598519]
#  [0.10877338 0.12195474 3.07394502 0.25542201]
#  [1.10795896 2.19219941 2.25157391 0.98716671]
#  [0.58465816 6.23263323 1.7218503  0.29701724]]

# %% [markdown]
# Explanation:
#
# np.random.exponential(scale=1.0, size=(4, 4)):
# np.random: This accesses the random number generation module within NumPy.
# exponential(): This function generates random samples from an exponential distribution.
# scale=1.0: This parameter determines the scale parameter (beta) of the exponential distribution. The default is 1.0.
# size=(4, 4): This parameter specifies the shape of the output array. We want a 4x4 matrix, so we set size=(4, 4).
# The generated random array is stored in the variable exponential_array.
# print(...): These lines simply print a descriptive message and the resulting exponential_array.

# %% [markdown]
# 2. Create a random 100000x1 array from the same exponential distribution and visualize the distribution histogram along with uniform and normal distributions. Use the code given below and do the necessary changes. Change the number of bins and the plot view to make the visualization better

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

# Create a random 100000x1 array from the same exponential distribution
exponential_data = np.random.exponential(scale=1.0, size=100000)

plt.hist(np.random.rand(100000), density=True, bins=100, histtype="step", color="blue", label="Uniform")
plt.hist(np.random.randn(100000), density=True, bins=100, histtype="step", color="red", label="Normal")
plt.hist(exponential_data, density=True, bins=1000, histtype="step", color="red", label="Exponential")


plt.axis([-5, 10, 0, 1.1]) # Adjust the x-axis range to better visualize the exponential distribution
plt.legend(loc = "upper right")
plt.title("Exponential distributions")
plt.xlabel("Value")
plt.ylabel("Density")
plt.show()

# %% [markdown]
#   3. Using matplotlib, plot the Z = X**2 + Y**2 in a 3D plot. Limit the x and y values to [-5, 5].

# %%
import matplotlib.pyplot as plt
import numpy as np

# Create a grid of x and y values
x = np.linspace(-5, 5, 100)
y = np.linspace(-5, 5, 100)
X, Y = np.meshgrid(x, y)

# Calculate Z
Z = X**2 + Y**2

# Create a 3D plot
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Plot the surface
ax.plot_surface(X, Y, Z, cmap='viridis')

# Set labels
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
ax.set_title('3D plot of Z = X^2 + Y^2')

plt.show()

# %% [markdown]
# **Explanation:**
#
# *   **`import matplotlib.pyplot as plt` and `import numpy as np`**: These lines import the necessary libraries: `matplotlib.pyplot` for plotting and `numpy` for numerical operations.
# *   **`x = np.linspace(-5, 5, 100)` and `y = np.linspace(-5, 5, 100)`**: These create arrays of 100 evenly spaced values between -5 and 5 for both the x and y axes.
# *   **`X, Y = np.meshgrid(x, y)`**: This creates a grid from the x and y arrays. `X` and `Y` are 2D arrays where each element corresponds to a point on the grid.
# *   **`Z = X**2 + Y**2`**: This calculates the corresponding Z values for each (X, Y) point on the grid based on the equation Z = X² + Y².
# *   **`fig = plt.figure()`**: This creates a new figure for the plot.
# *   **`ax = fig.add_subplot(111, projection='3d')`**: This adds a 3D subplot to the figure.
# *   **`ax.plot_surface(X, Y, Z, cmap='viridis')`**: This plots the 3D surface using the calculated X, Y, and Z values. `cmap='viridis'` sets the color map for the surface.
# *   **`ax.set_xlabel('X')`, `ax.set_ylabel('Y')`, `ax.set_zlabel('Z')`, `ax.set_title('3D plot of Z = X^2 + Y^2')`**: These lines set the labels for the axes and the title of the plot.
# *   **`plt.show()`**: This displays the generated plot.

# %% [markdown]
# 4. Calculate the pearson standard coefficient and spearman rank correlation for the [HP, Attack, Defense, Sp. Ark, Sp. Def, Speed] features in the seaborn tutorial.ipynb. Visualize the
# results using heatmaps. Make sure the values are displaced in the heatmap as well.

# %%
# Pandas for managing datasets
import pandas as pd

# %%
# Matplotlib for additional customization
from matplotlib import pyplot as plt
# %matplotlib inline
# Seaborn for plotting and styling
import seaborn as sns

# %%
# !wget -q https://elitedatascience.com/wp-content/uploads/2022/07/Pokemon.csv
# Read dataset
df = pd.read_csv('Pokemon.csv', index_col=0, encoding='latin')

# %%
# Display first 5 observations
df.head()
# Out:
#          Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# #
# 1   Bulbasaur  Grass  Poison    318  45      49       49       65       65
# 2     Ivysaur  Grass  Poison    405  60      62       63       80       80
# 3    Venusaur  Grass  Poison    525  80      82       83      100      100
# 4  Charmander   Fire     NaN    309  39      52       43       60       50
# 5  Charmeleon   Fire     NaN    405  58      64       58       80       65
#
#    Speed  Stage  Legendary
# #
# 1     45      1      False
# 2     60      2      False
# 3     80      3      False
# 4     65      1      False
# 5     80      2      False

# %% [markdown]
# Scatter Plot

# %%
# Scatterplot arguments
sns.lmplot(x='Attack', y='Defense', data=df,
           fit_reg=True, # No regression line
           hue='Stage')   # Color by evolution stage

# %% [markdown]
# Box Plots

# %%
# Boxplot
plt.figure(figsize=(9,6)) # Set plot dimensions
sns.boxplot(data=df)
# Out:
# <Axes: >

# %%
# Preprocess DataFrame
stats_df = df.drop(['Total', 'Stage', 'Legendary'], axis=1)

# New boxplot using stats_df
plt.figure(figsize=(9,6)) # Set plot dimensions
sns.boxplot(data=stats_df)
# Out:
# <Axes: >

# %% [markdown]
# Violin Plot

# %%
# Violin plot
plt.figure(figsize=(12,8)) # Set plot dimensions
sns.violinplot(x='Type 1', y='Attack', data=df)
# Out:
# <Axes: xlabel='Type 1', ylabel='Attack'>

# %% [markdown]
# Heat Map

# %%
stats_df = df.drop(['Name', 'Type 1', 'Type 2'], axis=1)
corr = stats_df.corr()

corr
# Out:
#               Total        HP    Attack   Defense   Sp. Atk   Sp. Def  \
# Total      1.000000  0.576591  0.670939  0.508694  0.680745  0.774383
# HP         0.576591  1.000000  0.306768  0.119782  0.236649  0.490978
# Attack     0.670939  0.306768  1.000000  0.491965  0.146312  0.369069
# Defense    0.508694  0.119782  0.491965  1.000000  0.187569  0.139912
# Sp. Atk    0.680745  0.236649  0.146312  0.187569  1.000000  0.522907
# Sp. Def    0.774383  0.490978  0.369069  0.139912  0.522907  1.000000
# Speed      0.506950 -0.040939  0.194701 -0.053252  0.411516  0.392656
# Stage      0.504224  0.249207  0.361321  0.270861  0.391712  0.358308
# Legendary  0.328412  0.172441  0.147486  0.141576  0.334159  0.215314
#
#               Speed     Stage  Legendary
# Total      0.506950  0.504224   0.328412
# HP        -0.040939  0.249207   0.172441
# Attack     0.194701  0.361321   0.147486
# Defense   -0.053252  0.270861   0.141576
# Sp. Atk    0.411516  0.391712   0.334159
# ...

# %%
# Heatmap
plt.figure(figsize=(9,8))
sns.heatmap(corr)
# Out:
# <Axes: >

# %%
# Select only the required features for correlation analysis
features = ['HP', 'Attack', 'Defense', 'Sp. Atk', 'Sp. Def', 'Speed']
selected_df = df[features]

# Calculate Pearson correlation coefficient
pearson_corr = selected_df.corr(method='pearson')

# Calculate Spearman rank correlation
spearman_corr = selected_df.corr(method='spearman')

print("Pearson Correlation Matrix:")
print(pearson_corr)
print("\nSpearman Rank Correlation Matrix:")
print(spearman_corr)
# Out:
# Pearson Correlation Matrix:
#                HP    Attack   Defense   Sp. Atk   Sp. Def     Speed
# HP       1.000000  0.306768  0.119782  0.236649  0.490978 -0.040939
# Attack   0.306768  1.000000  0.491965  0.146312  0.369069  0.194701
# Defense  0.119782  0.491965  1.000000  0.187569  0.139912 -0.053252
# Sp. Atk  0.236649  0.146312  0.187569  1.000000  0.522907  0.411516
# Sp. Def  0.490978  0.369069  0.139912  0.522907  1.000000  0.392656
# Speed   -0.040939  0.194701 -0.053252  0.411516  0.392656  1.000000
#
# Spearman Rank Correlation Matrix:
#                HP    Attack   Defense   Sp. Atk   Sp. Def     Speed
# HP       1.000000  0.539356  0.390014  0.363993  0.566837  0.054014
# Attack   0.539356  1.000000  0.541506  0.161862  0.386198  0.226590
# Defense  0.390014  0.541506  1.000000  0.258751  0.250028 -0.033235
# Sp. Atk  0.363993  0.161862  0.258751  1.000000  0.561665  0.384759
# Sp. Def  0.566837  0.386198  0.250028  0.561665  1.000000  0.403588
# ...

# %%
# Create heatmaps for both correlation types
fig, axes = plt.subplots(1, 2, figsize=(16, 6))

# Pearson correlation heatmap
sns.heatmap(pearson_corr,
            annot=True,  # Show values in heatmap
            cmap='coolwarm',
            center=0,
            square=True,
            fmt='.3f',  # Format values to 3 decimal places
            ax=axes[0])
axes[0].set_title('Pearson Correlation Heatmap\n[HP, Attack, Defense, Sp. Atk, Sp. Def, Speed]',
                  fontsize=12, pad=20)

# Spearman correlation heatmap
sns.heatmap(spearman_corr,
            annot=True,  # Show values in heatmap
            cmap='coolwarm',
            center=0,
            square=True,
            fmt='.3f',  # Format values to 3 decimal places
            ax=axes[1])
axes[1].set_title('Spearman Rank Correlation Heatmap\n[HP, Attack, Defense, Sp. Atk, Sp. Def, Speed]',
                  fontsize=12, pad=20)

plt.tight_layout()
plt.show()

# %% [markdown]
# **Explanation of Correlation Analysis:**
#
# 1. **Pearson Correlation Coefficient**: Measures the linear relationship between two variables. Values range from -1 to 1, where:
#    - 1 indicates a perfect positive linear relationship
#    - 0 indicates no linear relationship
#    - -1 indicates a perfect negative linear relationship
#
# 2. **Spearman Rank Correlation**: Measures the monotonic relationship between two variables (not necessarily linear). It works by ranking the data and then calculating the correlation of the ranks.
#
# **Key Observations from the Heatmaps:**
# - Both correlation matrices show values ranging from -1 to 1
# - The diagonal always shows 1.0 (perfect correlation of each feature with itself)
# - The `annot=True` parameter ensures all correlation values are displayed on the heatmap
# - The `coolwarm` colormap makes it easy to distinguish positive (red) from negative (blue) correlations
# - Features like Attack and Defense might show interesting correlation patterns with other stats
